# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base')

# %%
# %%capture
pip install -r relations_extraction/requirements.txt

# %%
os.chdir('/content/drive/MyDrive/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/src')

# %%
# %run distant_supervision.py
# Out:
# Loading KB from: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/kb_data/600_sample_data.json
# Loaded 637 KB records
# Loading pre-extracted entities from: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/entity_data/original/medical_entities_full.json
# Loaded entities for 10015 QAs
# Loading entity ID mapping from: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/entity_data/original/medical_entities_dict.json
# Loaded 20481 word-type pairs mapping to entity IDs
#
# Generating training data from Question + Answer + Context...
# Processing KB records: 100%|██████████| 637/637 [00:00<00:00, 3727.53it/s]
# Generated 11135 training samples
#   From Question: 2853 (25.6%)
#   From Answer: 2826 (25.4%)
#   From Context: 5456 (49.0%)
#
# Relation distribution:
#   HAS_SYMPTOM: 3748
#   TREATED_BY: 2945
#   AFFECTS: 1805
#   DIAGNOSED_BY: 1585
#   LOCATED_IN: 570
#   PREVENTED_BY: 482
#
# Performing stratified split by relation type...
#
# Relation distribution before split:
#   AFFECTS: 1805 samples
#   DIAGNOSED_BY: 1585 samples
#   HAS_SYMPTOM: 3748 samples
#   LOCATED_IN: 570 samples
#   PREVENTED_BY: 482 samples
#   TREATED_BY: 2945 samples
#   HAS_SYMPTOM: train=2998, val=374, test=376
#   AFFECTS: train=1444, val=180, test=181
#   TREATED_BY: train=2356, val=294, test=295
#   DIAGNOSED_BY: train=1268, val=158, test=159
#   PREVENTED_BY: train=385, val=48, test=49
#   LOCATED_IN: train=456, val=57, test=57
#
# ============================================================
# Final split:
#   Train: 8907 samples
#   Val: 1111 samples
#   Test: 1117 samples
# ============================================================
#
# Relation types per split:
#   Train: 6 types - ['AFFECTS', 'DIAGNOSED_BY', 'HAS_SYMPTOM', 'LOCATED_IN', 'PREVENTED_BY', 'TREATED_BY']
#   Val: 6 types - ['AFFECTS', 'DIAGNOSED_BY', 'HAS_SYMPTOM', 'LOCATED_IN', 'PREVENTED_BY', 'TREATED_BY']
#   Test: 6 types - ['AFFECTS', 'DIAGNOSED_BY', 'HAS_SYMPTOM', 'LOCATED_IN', 'PREVENTED_BY', 'TREATED_BY']
# Saved: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/data/train.json
# Saved: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/data/val.json
# Saved: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/data/test.json

# %%
# %run train.py
# Out:
# ============================================================
# TRAINING RELATION EXTRACTION MODEL
# ============================================================
#
# Device: cuda
#
# Loading data...
# Train samples: 8907
# Val samples: 1111
#
# Loading tokenizer and model...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Starting training...
# Epochs: 3
# Batch size: 16
# Learning rate: 2e-05
#
# ============================================================
# Epoch 1/3
# ============================================================
# Training: 100%|██████████| 557/557 [06:27<00:00,  1.44it/s, loss=0.0446, acc=0.6691]
# Train Loss: 0.9579 | Train Acc: 0.6691
# Evaluating: 100%|██████████| 70/70 [00:14<00:00,  4.88it/s]
# Val Loss: 0.1926 | Val Acc: 0.9541
#
# Saved best model to /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/models/vihealthbert_re/pytorch_model.bin
# Saved tokenizer and config to /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/models/vihealthbert_re
#
# ============================================================
# Epoch 2/3
# ============================================================
# Training: 100%|██████████| 557/557 [06:27<00:00,  1.44it/s, loss=0.0126, acc=0.9790]
# Train Loss: 0.0995 | Train Acc: 0.9790
# Evaluating: 100%|██████████| 70/70 [00:14<00:00,  4.83it/s]
# Val Loss: 0.0910 | Val Acc: 0.9802
#
# Saved best model to /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/models/vihealthbert_re/pytorch_model.bin
# Saved tokenizer and config to /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/models/vihealthbert_re
#
# ============================================================
# Epoch 3/3
# ============================================================
# Training: 100%|██████████| 557/557 [06:28<00:00,  1.44it/s, loss=0.0105, acc=0.9930]
# Train Loss: 0.0376 | Train Acc: 0.9930
# Evaluating: 100%|██████████| 70/70 [00:14<00:00,  4.87it/s]
# Val Loss: 0.0788 | Val Acc: 0.9856
#
# Saved best model to /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/models/vihealthbert_re/pytorch_model.bin
# Saved tokenizer and config to /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/models/vihealthbert_re
#
# ============================================================
# Training complete!
# Best Val Acc: 0.9856
# ============================================================
#
# Saved training plot to: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/models/vihealthbert_re/training_history.png
#
# ============================================================
# EVALUATING ON TEST SET
# ============================================================
# Test samples: 1117
# Actual relation types in test data: ['AFFECTS', 'DIAGNOSED_BY', 'HAS_SYMPTOM', 'LOCATED_IN', 'PREVENTED_BY', 'TREATED_BY']
# Loaded best model from: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/models/vihealthbert_re/pytorch_model.bin
# Evaluating: 100%|██████████| 70/70 [00:14<00:00,  4.75it/s]
# Test Loss: 0.0690
# Test Acc: 0.9857
#
# ============================================================
# CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#   TREATED_BY     0.9829    0.9763    0.9796       295
#  HAS_SYMPTOM     0.9841    0.9894    0.9867       376
# DIAGNOSED_BY     0.9875    0.9937    0.9906       159
#      AFFECTS     1.0000    0.9945    0.9972       181
# PREVENTED_BY     0.9583    0.9388    0.9485        49
#   LOCATED_IN     0.9828    1.0000    0.9913        57
#
#     accuracy                         0.9857      1117
#    macro avg     0.9826    0.9821    0.9823      1117
# weighted avg     0.9857    0.9857    0.9857      1117
#
#
# ============================================================
# CONFUSION MATRIX
# ============================================================
#
# Relation types:
#   [0] TREATED_BY
#   [1] HAS_SYMPTOM
#   [2] DIAGNOSED_BY
#   [3] AFFECTS
#   [4] PREVENTED_BY
#   [6] LOCATED_IN
#
# Confusion Matrix:
# Rows = True labels, Columns = Predictions
# [[288   6   0   0   1   0]
#  [  2 372   2   0   0   0]
#  [  0   0 158   0   1   0]
#  [  0   0   0 180   0   1]
#  [  3   0   0   0  46   0]
#  [  0   0   0   0   0  57]]
#
# Per-class Accuracy:
#   TREATED_BY: 0.9763 (288/295)
#   HAS_SYMPTOM: 0.9894 (372/376)
#   DIAGNOSED_BY: 0.9937 (158/159)
#   AFFECTS: 0.9945 (180/181)
#   PREVENTED_BY: 0.9388 (46/49)
#   LOCATED_IN: 1.0000 (57/57)
#
# ============================================================
# EVALUATION COMPLETE
# ============================================================

# %%
# %run extract.py
# Out:
# ============================================================
# EXTRACTING RELATIONS
# ============================================================
#
# Device: cuda
#
# Loading model...
# Loaded model from /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/models/vihealthbert_re/pytorch_model.bin
#
# Loading data...
# Loading KB from: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/kb_data/600_sample_data.json
# Loaded 637 KB records
# Loading pre-extracted entities from: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/entity_data/original/medical_entities_full.json
# Loaded entities for 10015 QAs
# Loading entity ID mapping from: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/entity_data/original/medical_entities_dict.json
# Loaded 20481 word-type pairs mapping to entity IDs
#
# Extracting relations from Question + Answer + Context...
# Processing KB records: 100%|██████████| 637/637 [05:18<00:00,  2.00it/s]
# Extracted 16812 relations
#   From Question: 4231 (25.2%)
#   From Answer: 4545 (27.0%)
#   From Context: 8036 (47.8%)
#
# Saved relations to: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/output/relations.json
# Saved statistics to: /content/drive/.shortcut-targets-by-id/17Jvl1vlEkMSzyuQ99QRJzOvfq-rBj0mP/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base/relations_extraction/output/statistics.json
#
# ============================================================
# EXTRACTION STATISTICS
# ============================================================
# Total relations: 16812
# Unique head entities: 1360
# Unique tail entities: 1366
# Average confidence: 0.9881
#
# Relation type distribution:
#   TREATED_BY: 5502
#   DIAGNOSED_BY: 4037
#   HAS_SYMPTOM: 3746
#   AFFECTS: 1817
#   PREVENTED_BY: 1106
#   LOCATED_IN: 604
# ============================================================
