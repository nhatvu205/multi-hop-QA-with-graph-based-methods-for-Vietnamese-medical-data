# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/DO_AN_DS_KI_1_NAM_3/DS201/Nvu/knowledge_base')

# %%
import json

with open('medical_entities_dict.json', 'r', encoding='utf-8') as f:
    original_dict = json.load(f)

# %%
from entity_linking.entity_normalization import *

normalized_dict = create_normalized_dictionary(
    original_dict,
    similarity_threshold=0.85
)
# Out:
# ...
# ENTITY NORMALIZATION & CLUSTERING
# ...
#
# Input:
#    • Total entities: 20481
# Clustering 20481 entities...
# Processed 100/20481 entities...
# Processed 200/20481 entities...
# Processed 300/20481 entities...
# Processed 400/20481 entities...
# Processed 500/20481 entities...
# Processed 700/20481 entities...
# Processed 800/20481 entities...
# Processed 900/20481 entities...
# Processed 1000/20481 entities...
# Processed 1100/20481 entities...
# Processed 1200/20481 entities...
# Processed 1300/20481 entities...
# Processed 1400/20481 entities...
# Processed 1500/20481 entities...
# Processed 1600/20481 entities...
# Processed 1700/20481 entities...
# Processed 1800/20481 entities...
# Processed 1900/20481 entities...
# Processed 2100/20481 entities...
# Processed 2200/20481 entities...
# Processed 2300/20481 entities...
# Processed 2400/20481 entities...
# Processed 2600/20481 entities...
# Processed 2700/20481 entities...
# Processed 2800/20481 entities...
# ...

# %%
mapping = create_entity_mapping(original_dict, normalized_dict)

# %%
with open('entity_linking/entity_id_mapping.json', 'w', encoding='utf-8') as f:
    json.dump(mapping, f, ensure_ascii=False, indent=2)

print(f"Saved: entity_id_mapping.json")
# Out:
# Saved: entity_id_mapping.json

# %%
save_normalized_dictionary(normalized_dict, 'entity_linking/normalized_entity_dict.json')
# Out:
# Saved: entity_linking/normalized_entity_dict.json

# %%
from entity_linking.analyze_normalization import *

# Analyze
original, normalized, mapping = load_data()
analyze_normalization(original, normalized, mapping)
# Out:
# Loading data...
#
# ...
# ENTITY NORMALIZATION ANALYSIS
# ...
#
# Basic Statistics:
#    • Original entities: 20481
#    • Normalized entities: 13195
#    • Reduction: 7286 entities (35.6%)
#    • Mapping entries: 19545
#
# Merging Statistics:
#    • Entities created by merging: 3582 (27.1%)
#    • Original entities merged: 10868
#    • Avg entities per merge: 3.0
#    • Max entities merged: 115
#
# Entity Type Distribution:
#
#    Type                        Original Normalized  Reduction
#    ------------------------------------------------------------
#    DIAGNOSTICS                      738        454      38.5%
#    DISEASESYMTOM                   9578       5790      39.5%
#    DRUGCHEMICAL                    5061       3555      29.8%
#    MEDDEVICETECHNIQUE              1272        948      25.5%
#    ORGAN                           2130       1330      37.6%
#    PREVENTIVEMED                    276        204      26.1%
#    SURGERY                          990        596      39.8%
# ...
